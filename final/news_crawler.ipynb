# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta
start = datetime.strptime("2017/01/01", "%Y/%m/%d")
month_list = []
for i in range(0,5):
    month_list.append((start + relativedelta(months=i)).strftime('%Y/%m/%d'))
month_list
# Out:
# ['2017/01/01', '2017/02/01', '2017/03/01', '2017/04/01', '2017/05/01']

# %%
def news(a):
    import urllib.request
    from bs4 import BeautifulSoup
    import requests, sys, time
    from random import randint

    month_url = "http://www.taipeitimes.com/News/main/history/"+a
    month_headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36'}
    month_req = urllib.request.Request(url = month_url, headers = month_headers)
    month_page = urllib.request.urlopen(month_req)
    month_content = month_page.read()
    month_sp = BeautifulSoup(month_content, 'html.parser')
    day_list_h = []
    for d in month_sp.find_all('tr', {'class':'date'}):
        day_list_h.append(d)
    month_sp1 = BeautifulSoup(str(day_list_h), 'html.parser')
    day_list = []
    for d1 in month_sp1.find_all('a'):
        day_list.append(d1.get('href'))
    contexts = []
    contexts_list = []
    for i in range(len(day_list)):
        day_url = "http://www.taipeitimes.com/"+day_list[i]
        day_headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36'}
        day_req = urllib.request.Request(url = day_url, headers = day_headers)
        day_page = urllib.request.urlopen(day_req)
        day_content = day_page.read()
        day_sp = BeautifulSoup(day_content, 'html.parser')
        for c in day_sp.find_all('div', {'class':'list_areaH'}):
            contexts.append(c)
        day_sp1 = BeautifulSoup(str(contexts), 'html.parser')
        for c1 in day_sp1.find_all('a'):
            contexts_list.append(c1.get('href'))
    tag2 = []
    news_text = []
    for i in range(len(contexts_list)):
        con_url = "http://www.taipeitimes.com/"+contexts_list[i]
        con_headers = {'User-Agent':'User-Agent:Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.98 Safari/537.36 Vivaldi/1.6.689.40'}
        con_req = urllib.request.Request(url = con_url, headers=con_headers)
        con_page = urllib.request.urlopen(con_req)
        con_content = con_page.read()
        con_sp = BeautifulSoup(con_content, 'html.parser')
        tag = []
        news = []
        for t in con_sp.find_all('div', {'class':'etitle_c1'}):
            tag.append(t)
        con_sp2 = BeautifulSoup(str(tag), 'html.parser')
        for t2 in con_sp2.find_all('a'):
            tag2.append(t2.string)
        for n in con_sp.find_all('div', {'class':'text'}):
            news.append(n)
            con_sp3 = BeautifulSoup(str(news), 'html.parser')
            news_text.append(con_sp3.get_text())
            #time.sleep(randint(2,10))
    return tag2, news_text
    #print(tag2, news_text)

# %%
#5月
tag2, news_text = news(month_list[4])

# %%
news_dict5={"Type":tag2,"Content":news_text}
import pandas as pd
news_df5 = pd.DataFrame(news_dict5)
news_df5
# Out:
#                                                 Content             Type
# 0     [\nAn exchange of gunfire and a three-hour sta...       Front Page
# 1     [\nHundreds of migrant workers and members of ...       Front Page
# 2     [\nThe Philippines followed up an ASEAN summit...       Front Page
# 3     [\nSouth Korea said the US had reaffirmed it w...       Front Page
# 4     [\nTaiwan’s Tai Tzu-ying (戴資穎), the world’s to...       Front Page
# 5     [\nThe nation’s military ties with the US have...      Taiwan News
# 6     [\nLiberty Times (LT): Despite public opinion ...      Taiwan News
# 7     [\nChinese Nationalist Party (KMT) chairmanshi...      Taiwan News
# 8     [\nThe nation should garner the support of the...      Taiwan News
# 9     [\nA regulation requiring that amateur radio o...      Taiwan News
# 10    [\nThe Directorate-General of Highways (DGH) y...      Taiwan News
# 11    [\nMysterious stone stacks that appeared in th...      Taiwan News
# 12    [\nFrom today, to gain a driver’s license, app...      Taiwan News
# 13    [\nMore than 13,000 people have used the onlin...      Taiwan News
# 14    [\nMore than 50 firms listed on the local main...         Business
# 15    [\nFlat-panel maker Innolux Corp (群創) became t...         Business
# 16    [\nThe US has kept Taiwan off an intellectual ...         Business
# 17    [\nNew Balance Athletic Shoe Inc has won a rar...         Business
# 18    [\nIf you want to be at the epicenter of globa...         Business
# 19    [\nCPC Corp, Taiwan (CPC, 台灣中油) yesterday said...         Business
# 20    [\nThe urban farm craze is finding fertile gro...         Business
# 21    [\nA pair of filmmakers at the prestigious TED...         Business
# 22    [\nTaiwanese entrepreneur Matilda Ho (何瑞怡) is ...         Business
# 23    [\nGrowth in China’s manufacturing sector last...         Business
# 24    [\nThe world’s leading container shipping comp...         Business
# 25    [\n“Granny Bear” has proved a big hit in Bulga...         Business
# 26    [\nItalians are watching their flag carrier Al...         Business
# 27    [\nUS President Donald Trump’s plans to slash ...         Business
# 28    [\nA hacker claims to have followed through on...         Business
# 29    [\nITALYAuthorities chase AmazonTax authoritie...         Business
# ...                                                 ...              ...
# 7302  [\nAs President Tsai Ing-wen (蔡英文) nears the f...       Editorials
# 7303  [\nTaiwan’s food safety management system has ...       Editorials
# 7304  [\nClowns in parliamentAnother day, another fr...       Editorials
# 7305  [\nAfter election hacks in the US and France, ...       Editorials
# 7306  [\nThe initial case was bizarre enough that it...       Editorials
# 7307  [\nSaracens director Mark McCall said “there’s...           Sports
# 7308  [\nLamigo Monkeys slugger Wang Po-jung kept up...           Sports
# 7309  [\nThe Cricket Australia (CA) board has said t...           Sports
# 7310  [\nManchester City manager Pep Guardiola is ce...           Sports
# 7311  [\nLewis Hamilton yesterday won the Spanish Gr...           Sports
# 7312  [\nThe head of women’s tennis has condemned Mu...           Sports
# 7313  [\nThere is something wrong with firing a 160k...           Sports
# 7314  [\nA piece of history and a measure of revenge...           Sports
# 7315  [\nThe New York Mets returned to baseball prom...           Sports
# 7316  [\nParis city leaders yesterday welcomed visit...           Sports
# 7317  [\nChinese President Xi Jinping (習近平) yesterda...       World News
# 7318  [\nA leading candidate to head the WHO was acc...       World News
# 7319  [\nThe top prize of the Venice Biennale, the w...       World News
# 7320  [\nBefore dawn in the Indian Himalayas, scores...       World News
# 7321  [\nCivilians and rebels yesterday began evacua...       World News
# 7322  [\nVenezuelans in cars and on motorcycles, bik...       World News
# 7323  [\nIn the most cashless society on the planet,...       World News
# 7324  [\nFew couples would celebrate their wedding a...       World News
# 7325  [\nArcheological workers in Egypt unearthed an...       World News
# 7326  [\nUKRAINEPortugal wins EurovisionPortugal’s S...       World News
# 7327  [\nConsuming cheese, milk and yogurt — even fu...         Features
# 7328  [\nCommonly prescribed painkillers including i...         Features
# 7329  [\nAt HotBlack Coffee, a cafe in downtown Toro...         Features
# 7330  [\n魚與熊掌不可兼得(yu2 yu3 xiong2 zhang3 bu4 ke3 jian...  Bilingual Pages
# 7331  [\nA: Those two always seem to be at each othe...  Bilingual Pages
#
# [7332 rows x 2 columns]

# %%
news_df5.to_csv('news5.csv')

# %%
#4月
tag2_4, news_text_4 = news(month_list[3])

# %%
news_dict4={"Type":tag2_4,"Content":news_text_4}
import pandas as pd
news_df4 = pd.DataFrame(news_dict4)
news_df4
# Out:
#                                                  Content             Type
# 0      [\nThe Taipei District Court yesterday acquitt...       Front Page
# 1      [\nLeaders of the Sunflower movement yesterday...       Front Page
# 2      [\nTaiwan’s export-import bank over the past f...       Front Page
# 3      [\nUS President Donald Trump on Thursday set t...       Front Page
# 4      [\nOusted South Korean president Park Geun-hye...       Front Page
# 5      [\nThe Chinese Nationalist Party (KMT) caucus ...      Taiwan News
# 6      [\nThe legislature yesterday passed an amendme...      Taiwan News
# 7      [\nExecutive Yuan spokesman Hsu Kuo-yung (徐國勇)...      Taiwan News
# 8      [\nDetained human rights advocate Lee Ming-che...      Taiwan News
# 9      [\nChinese Nationalist Party (KMT) members who...      Taiwan News
# 10     [\nResidents of military dependents’ villages ...      Taiwan News
# 11     [\nThe government on Thursday said it welcomes...      Taiwan News
# 12     [\nThe Taipei City Government and the Taiwan R...      Taiwan News
# 13     [\nThe Taipei District Court yesterday sentenc...      Taiwan News
# 14     [\nThe average monthly salary for young employ...      Taiwan News
# 15     [\nDisagreements were sparked earlier this wee...      Taiwan News
# 16     [\nThe reassembled Xinbeitou Train Station in ...      Taiwan News
# 17     [\nThe National Freeway Bureau is to pay Far E...      Taiwan News
# 18     [\nAuthorities in central Taiwan on Tuesday ar...      Taiwan News
# 19     [\nSOCIETYWinning number announcedHolders of 1...      Taiwan News
# 20     [\nHon Hai Precision Industry Co (鴻海精密), a key...         Business
# 21     [\nChailease Group (中租集團), which includes Chai...         Business
# 22     [\nBerlin yesterday angrily protested after th...         Business
# 23     [\nTaiwanese makers of carbon and alloy steel ...         Business
# 24     [\nCredit Suisse Group AG, some of its employe...         Business
# 25     [\nGarment manufacturer Quang Viet Enterprise ...         Business
# 26     [\nUS President Donald Trump’s administration ...         Business
# 27     [\nSouth Africa’s rand headed for its biggest ...         Business
# 28     [\nApple Inc has prevented efforts by Australi...         Business
# 29     [\nToshiba Corp shares yesterday surged as Jap...         Business
# ...                                                  ...              ...
# 29077  [\nIf you binged on sugar last year, you are p...         Business
# 29078  [\nAsian stocks on Friday slid from fresh 22-m...         Business
# 29079  [\nThe euro on Friday rose against the US doll...         Business
# 29080  [\nTRANSPORTDidi raises US$5.5bnChina’s ride-h...         Business
# 29081  [\nOn Tuesday, a bill to recover wrongfully pa...       Editorials
# 29082  [\nOn April 14, the US Department of the Treas...       Editorials
# 29083  [\nFriday marked the 65th anniversary of the d...       Editorials
# 29084  [\n“‘Who rules here?’ I asked.“They said: ‘The...       Editorials
# 29085  [\nStrict British and US counterterrorism laws...       Editorials
# 29086  [\nThe pound’s sharp fall since the Brexit ref...       Editorials
# 29087  [\nJohn Wall had that look in his eye at morni...           Sports
# 29088  [\nClippers coach Doc Rivers put it simply whe...           Sports
# 29089  [\nThe Boston Celtics kept reminding each othe...           Sports
# 29090  [\nKaohsiung-based Taipower showed they are th...           Sports
# 29091  [\nSerie A leaders Juventus was held by hosts ...           Sports
# 29092  [\nThe Waikato Chiefs were stretched to beat t...           Sports
# 29093  [\nWhile the Anaheim Ducks dominated the puck ...           Sports
# 29094  [\nThe City of Brotherly Love turned a boring ...           Sports
# 29095  [\nBrazil and superstar Neymar were the first ...           Sports
# 29096  [\nOut on Bermuda’s Great Sound, on a fast cat...           Sports
# 29097  [\nGOLFHsu shows improvementAt the Yeangder He...           Sports
# 29098  [\nProtesters lit buses on fire, blocked roads...       World News
# 29099  [\nA US woman convicted of espionage was depor...       World News
# 29100  [\nUS President Donald Trump on Saturday faced...       World News
# 29101  [\nLaden with whisky and baby milk, the first ...       World News
# 29102  [\nUS Marines yesterday returned to Afghanista...       World News
# 29103  [\nNineteen people were killed and 21 injured ...       World News
# 29104  [\nMay  1  to  May  6The day before they were ...         Features
# 29105  [\nPrince Harry has said in a new interview th...  Bilingual Pages
# 29106  [\nA: I have this dull ache in my right ear, a...  Bilingual Pages
#
# [29107 rows x 2 columns]

# %%
news_df4.to_csv('news4.csv')

# %%
#3月
tag2_3, news_text_3 = news(month_list[2])

# %%
news_dict3={"Type":tag2_3,"Content":news_text_3}
import pandas as pd
news_df3 = pd.DataFrame(news_dict3)
news_df3
# Out:
#                                                  Content             Type
# 0      [\nPresident Tsai Ing-wen (蔡英文) yesterday pled...       Front Page
# 1      [\nFree Taiwan Party Chairman (FTP) Tsay Ting-...       Front Page
# 2      [\nThe Centers for Disease Control (CDC) has c...       Front Page
# 3      [\nA high-level North Korean delegation arrive...       Front Page
# 4      [\nSouth Korean prosecutors yesterday said the...       Front Page
# 5      [\nPremier Lin Chuan (林全) yesterday highlighte...      Taiwan News
# 6      [\nThree students and a fourth person were arr...      Taiwan News
# 7      [\nChinese Nationalist Party (KMT) Chairwoman ...      Taiwan News
# 8      [\nKeisho Aoyama, the first Japanese to receiv...      Taiwan News
# 9      [\nChuo University president Shozaburo Sakai o...      Taiwan News
# 10     [\nUnit 27 veteran Chung Yi-jen (鍾逸人) — the on...      Taiwan News
# 11     [\nPro-China unification advocates and histori...      Taiwan News
# 12     [\nAbout 500 people yesterday participated in ...      Taiwan News
# 13     [\nA claim by Taiwan Jury Association chairman...      Taiwan News
# 14     [\nNew regulations announced by the Council of...      Taiwan News
# 15     [\nEven with medical center copayment fees set...      Taiwan News
# 16     [\nThe number of foreign domestic employees in...      Taiwan News
# 17     [\nTen people have been arrested at Taiwan Tao...      Taiwan News
# 18     [\nHandset chip designer MediaTek Inc (聯發科) on...         Business
# 19     [\nChinese handset maker Xiaomi Corp (小米) yest...         Business
# 20     [\nPneumatic components supplier Airtac Intern...         Business
# 21     [\nMajor property brokers reported a noticeabl...         Business
# 22     [\nHon Hai Precision Industry Co (鴻海精密) is to ...         Business
# 23     [\nAsustek Computer Inc (華碩) foresees its tabl...         Business
# 24     [\nThe Ministry of Transportation and Communic...         Business
# 25     [\nStruggling with customers unable to pay on ...         Business
# 26     [\nCLSA Ltd, a brokerage owned by China’s Citi...         Business
# 27     [\nChina plans to target broad money supply gr...         Business
# 28     [\nVietJet Aviation Joint Stock Co yesterday s...         Business
# 29     [\nAnother day, another shot across the bow. F...         Business
# ...                                                  ...              ...
# 31182  [\nAccording to today’s populists, “good jobs”...       Editorials
# 31183  [\nWith their gray-green waters and blue heron...       Editorials
# 31184  [\nLeicester City caretaker manager Craig Shak...           Sports
# 31185  [\nACF Fiorentina squandered a two-goal lead a...           Sports
# 31186  [\nRoger Federer showed few signs of rust afte...           Sports
# 31187  [\nKevin Durant returned from injury with a ba...           Sports
# 31188  [\nThe Montreal Canadiens found a way to win, ...           Sports
# 31189  [\nFormer champion Hsieh Su-wei was stunned by...           Sports
# 31190  [\nAn Australian yesterday was charged with he...       World News
# 31191  [\nMore than 10,000 armed police in China’s Xi...       World News
# 31192  [\nThailand’s prisons fail to meet internation...       World News
# 31193  [\nA shark has taken a dog at a popular Sydney...       World News
# 31194  [\nIn 2008, Juergen Kantner and his partner we...       World News
# 31195  [\nA growing population is straining water sup...       World News
# 31196  [\nRohingya Muslim refugee Ali Hasan is desper...       World News
# 31197  [\nThe Marshall Islands in the Pacific Ocean o...       World News
# 31198  [\nEngland’s mammoth inquiry into historical c...       World News
# 31199  [\nTurkish authorities on Monday arrested a re...       World News
# 31200  [\nA palm oil company in the Democratic Republ...       World News
# 31201  [\nRussia yesterday pledged to veto a Western-...       World News
# 31202  [\nSpaceX plans to launch two paying passenger...       World News
# 31203  [\nIn an office cubicle at the UN refugee agen...       World News
# 31204  [\nA routine training session in Canada’s Arct...       World News
# 31205  [\nEl Salvador’s widespread violence reached a...       World News
# 31206  [\nJewish community centers (JCC) and schools ...       World News
# 31207  [\nCAMBODIASeven girls drown in lakeSeven girl...       World News
# 31208  [\nHao Rui only took up skiing this winter, bu...         Features
# 31209  [\nTech-savvy sports enthusiasts will get thei...         Features
# 31210  [\nA circus in the US is under fire for bringi...  Bilingual Pages
# 31211  [\nA: Your dog is so cute, can I stroke her? E...  Bilingual Pages
#
# [31212 rows x 2 columns]

# %%
news_df3.to_csv('news3.csv')

# %%
#2月
tag2_2, news_text_2 = news(month_list[1])

# %%
news_dict2={"Type":tag2_2,"Content":news_text_2}
import pandas as pd
news_df2 = pd.DataFrame(news_dict2)
news_df2
# Out:
#                                                  Content             Type
# 0      [\nPresident Tsai Ing-wen (蔡英文) yesterday urge...       Front Page
# 1      [\nIn an extraordinary public showdown, US Pre...       Front Page
# 2      [\nThe US dollar yesterday headed for its wors...       Front Page
# 3      [\nThe French Canadian university student char...       Front Page
# 4      [\nEmployees and supporters of a Pakistani Mus...       Front Page
# 5      [\nPeople yesterday prepared fresh flowers and...      Taiwan News
# 6      [\nDemocratic Progressive Party Legislator Chi...      Taiwan News
# 7      [\nDue to festive feasting over the Lunar New ...      Taiwan News
# 8      [\nAn artist has drawn a comic series featurin...      Taiwan News
# 9      [\nDiver Cao Chien-shun (趙健舜) said his diving ...      Taiwan News
# 10     [\nDenmark wants the EU to roll back some fina...         Business
# 11     [\nFrench growth accelerated in the fourth qua...         Business
# 12     [\nNovartis AG is pushing ahead with one of it...         Business
# 13     [\nWal-Mart Stores Inc is scrapping its Shippi...         Business
# 14     [\nBritish mobile phone giant Vodafone Group P...         Business
# 15     [\nGerman insurance heavyweight Allianz SE is ...         Business
# 16     [\nLCD panel maker Innolux Corp (群創) lost its ...         Business
# 17     [\nChina’s rapid nuclear expansion will result...         Business
# 18     [\nJapan’s central bank yesterday hiked its ec...         Business
# 19     [\nA row over US visa bans might further weake...         Business
# 20     [\nTwo of the main contenders for the job of g...         Business
# 21     [\nGERMANYSurplus to hit record: IfoThe nation...         Business
# 22     [\nJapan’s Kurumi Nara provided the biggest sh...           Sports
# 23     [\nStruggling with star forward Kevin Love sid...           Sports
# 24     [\nNew England Patriots quarterback Tom Brady ...           Sports
# 25     [\nThe St Louis Cardinals were ordered to pay ...           Sports
# 26     [\nThe US Olympic Committee (USOC) said on Mon...           Sports
# 27     [\nGermany’s Annika Beck produced the first up...           Sports
# 28     [\nKevin de Bruyne believes Fernandinho’s retu...           Sports
# 29     [\nLeicester City striker Leonardo Ulloa has a...           Sports
# ...                                                  ...              ...
# 25326  [\nThe US’ long-term allies are bewildered abo...       Editorials
# 25327  [\nAs the water supply in some regions reaches...       Editorials
# 25328  [\nVenezuela is so short on food that tens of ...       Editorials
# 25329  [\nThe administration of US President Donald T...       Editorials
# 25330  [\nJose Mourinho was overcome with emotion aft...           Sports
# 25331  [\nReal Madrid coach Zinedine Zidane threw cau...           Sports
# 25332  [\nEngland coach Eddie Jones accused Italy of ...           Sports
# 25333  [\nMauricio Pochettino believes Harry Kane is ...           Sports
# 25334  [\nRickie Fowler of the US on Sunday breathed ...           Sports
# 25335  [\nDominic Thiem won the Rio Open on his favor...           Sports
# 25336  [\nIt is in Kuala Lumpur’s “Little India” neig...       World News
# 25337  [\nA militant killed by police in Indonesia af...       World News
# 25338  [\nAt least eight domestic tourists drowned an...       World News
# 25339  [\nUS security officers have yet to be authori...       World News
# 25340  [\nA fanciful idea that started out as a joke ...       World News
# 25341  [\nAustralia is failing to protect its female ...       World News
# 25342  [\nFrench National Front leader Marine Le Pen ...       World News
# 25343  [\nThousands of protesters have marched in Mos...       World News
# 25344  [\nThe studio lights dim, and the anchor taps ...       World News
# 25345  [\nGermany recorded more than 3,500 attacks ag...       World News
# 25346  [\nThe main Syrian opposition group at peace t...       World News
# 25347  [\nRainstorms and landslides in Chile killed f...       World News
# 25348  [\nThe body of Jose Antonio Reyes Lobos rests ...       World News
# 25349  [\nA float crashed during Rio de Janeiro’s wor...       World News
# 25350  [\nThe White House on Sunday did not rule out ...       World News
# 25351  [\nISRAELHospitals demand paymentA health offi...       World News
# 25352  [\nComing-of-age drama Moonlight won the covet...         Features
# 25353  [\nChinese Practice蜀犬吠日(shu2 quan3 fei4 ri4)Si...  Bilingual Pages
# 25354  [\nFollowing a restoration project lasting mor...  Bilingual Pages
# 25355  [\nA: Today is Wenchang Dijun’s birthday. We s...  Bilingual Pages
#
# [25356 rows x 2 columns]

# %%
news_df2.to_csv('news2.csv')

# %%
#1月
tag2_1, news_text_1 = news(month_list[0])

# %%
news_dict1={"Type":tag2_1,"Content":news_text_1}
import pandas as pd
news_df1 = pd.DataFrame(news_dict1)
news_df1
# Out:
#                                                  Content             Type
# 0      [\nThe first public forum on pension reform fa...       Front Page
# 1      [\nThe Chinese military has become alarmed by ...       Front Page
# 2      [\nPresident Tsai Ing-wen (蔡英文) yesterday urge...       Front Page
# 3      [\nThere is no space for Hong Kong independenc...       Front Page
# 4      [\nPanama does not expect any change in its re...       Front Page
# 5      [\nThe government’s efforts this year will foc...      Taiwan News
# 6      [\nAuthorities should not use the land they ex...      Taiwan News
# 7      [\nLiberty Times (LT): About NT$113.8 billion ...      Taiwan News
# 8      [\nThe Taipei District Court on Friday found a...      Taiwan News
# 9      [\nA slew of new measures and policies is to t...      Taiwan News
# 10     [\nThe Ministry of Science and Technology has ...      Taiwan News
# 11     [\nLocal comic book artists are collaborating ...      Taiwan News
# 12     [\nA gas leak at a fertilizer factory in Yilan...      Taiwan News
# 13     [\nTaiwanese yesterday geared up to welcome th...      Taiwan News
# 14     [\nMost world stocks markets finished last yea...         Business
# 15     [\nInvestors are showing no sign of turning th...         Business
# 16     [\nFrench companies would be required to guara...         Business
# 17     [\nBritain last year exported sparkling wines ...         Business
# 18     [\nJack Dorsey wants Twitter Inc’s users to kn...         Business
# 19     [\nA giant South Korean-built manned robot tha...         Business
# 20     [\n“I make my money for me,” declares Afghan b...         Business
# 21     [\nOne of Europe’s worst offenders on food was...         Business
# 22     [\nSMARTPHONESApple wants concessionsApple Inc...         Business
# 23     [\nLast year began with the election of Presid...       Editorials
# 24     [\nSince US president-elect Donald Trump won t...       Editorials
# 25     [\nUS president-elect Donald Trump has selecte...       Editorials
# 26     [\nPresident Tsai Ing-wen (蔡英文) has always ref...       Editorials
# 27     [\nEven through Beijing’s smog you can make ou...       Editorials
# 28     [\nAt Saks Off Fifth recently, an Ivanka Trump...       Editorials
# 29     [\nJames Harden on Friday recorded his seventh...           Sports
# ...                                                  ...              ...
# 29356  [\nThe market for a peculiar type of clay is l...         Business
# 29357  [\nFrom jobless young people hired to dig well...         Business
# 29358  [\nEver since President Tsai Ing-wen (蔡英文) of ...       Editorials
# 29359  [\nDepartment heads from Apple Inc’s environme...       Editorials
# 29360  [\nLast year ended with slightly higher foreca...       Editorials
# 29361  [\nSao Tome and Principe’s announcement that t...       Editorials
# 29362  [\nForeign governments concerned about climate...       Editorials
# 29363  [\nWell before Donald Trump was elected presid...       Editorials
# 29364  [\nAaron Rodgers threw four touchdown passes a...           Sports
# 29365  [\nArsene Wenger hailed Olivier Giroud’s stunn...           Sports
# 29366  [\nAuston Matthews put on a show for the Toron...           Sports
# 29367  [\nKyle Lowry relishes any chance to raise his...           Sports
# 29368  [\nTaiwan’s Chang Kai-chen advanced to the sec...           Sports
# 29369  [\nAn unbeaten 76 from opener Dean Elgar led a...           Sports
# 29370  [\nThe Burmese government yesterday pledged to...       World News
# 29371  [\nResidents in a small north Queensland State...       World News
# 29372  [\nTeetotaler Indian Prime Minister Narendra M...       World News
# 29373  [\nThe screams of a dozen Syrian and Palestini...       World News
# 29374  [\nChina will not allow anyone to use Hong Kon...       World News
# 29375  [\nGunmen armed with automatic rifles and pist...       World News
# 29376  [\nAt least 800 sub-Saharan African migrants o...       World News
# 29377  [\nA plane carrying 35 Russian diplomats expel...       World News
# 29378  [\nThis year, Hollywood has become “Hollyweed....       World News
# 29379  [\nKatherine Lotspeich was stopped cold by the...       World News
# 29380  [\nFourteen garden villages are to be built ac...       World News
# 29381  [\nUNITED STATESCarey struggles on stageMariah...       World News
# 29382  [\nYeh Wei-li (葉偉立) is known for his attractio...         Features
# 29383  [\nChinese practiceTo rein in the horse at the...  Bilingual Pages
# 29384  [\nOn Dec. 27, the National Central University...  Bilingual Pages
# 29385  [\nA: I’m mulling opening a joint stationery d...  Bilingual Pages
#
# [29386 rows x 2 columns]

# %%
news_df1.to_csv('news1.csv')
